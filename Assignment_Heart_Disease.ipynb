# %% [markdown]
# ### Load the Data

# %%
import pandas as pd
# data = 'heart_disease.csv'
show_data = pd.read_csv('heart_disease.csv')
show_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ### Compute Basic Statistics

# %%
basic_static = show_data.describe(include='all')
basic_static
# Out:
#        HeartDisease            BMI Smoking AlcoholDrinking  Stroke  \
# count        319795  319789.000000  319721          319680  319774
# unique            2            NaN       2               2       2
# top              No            NaN      No              No      No
# freq         292422            NaN  187843          297908  307706
# mean            NaN      28.325348     NaN             NaN     NaN
# std             NaN       6.356134     NaN             NaN     NaN
# min             NaN      12.020000     NaN             NaN     NaN
# 25%             NaN      24.030000     NaN             NaN     NaN
# 50%             NaN      27.340000     NaN             NaN     NaN
# 75%             NaN      31.420000     NaN             NaN     NaN
# max             NaN      94.850000     NaN             NaN     NaN
#
#         PhysicalHealth   MentalHealth DiffWalking     Sex AgeCategory    Race  \
# count    319778.000000  319781.000000      319762  319482      319751  319756
# ...

# %% [markdown]
# ### Handle Missing Data

# %%
# Check for missing values
missing_data  = show_data.isnull().sum()
missing_data
# Out:
# HeartDisease          0
# BMI                   6
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
# Encode categorical variables
data_encoded = pd.get_dummies(show_data,drop_first=True)
data_encoded
# Out:
#           BMI  PhysicalHealth  MentalHealth  SleepTime  HeartDisease_Yes  \
# 0       16.60             3.0          30.0        5.0             False
# 1       20.34             0.0           0.0        7.0             False
# 2       26.58            20.0          30.0        8.0             False
# 3       24.21             0.0           0.0        6.0             False
# 4       23.71            28.0           0.0        8.0             False
# ...       ...             ...           ...        ...               ...
# 319790  27.41             7.0           0.0        6.0              True
# 319791  29.84             0.0           0.0        5.0             False
# 319792  24.24             0.0           0.0        6.0             False
# 319793  32.81             0.0           0.0       12.0             False
# 319794  46.56             0.0           0.0        8.0             False
#
#         Smoking_Yes  AlcoholDrinking_Yes  Stroke_Yes  DiffWalking_Yes  \
# ...

# %% [markdown]
# ### Check for imbalance

# %%
# Check for imbalance in the target variable
heart_disease_check = show_data['HeartDisease'].value_counts()
heart_disease_check

# Calculate the imbalance ratio
imbalance_check = heart_disease_check / heart_disease_check.sum()
imbalance_check
# Out:
# HeartDisease
# No     0.914405
# Yes    0.085595
# Name: count, dtype: float64

# %%
show_data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the imbalance in the target variable
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
sns.countplot(x='HeartDisease', data=data)  # Corrected line
plt.title('Heart Disease Counts')

# Visualize the distribution of BMI
plt.subplot(1, 2, 2)
sns.histplot(show_data['BMI'], kde=True)
plt.title('BMI Distribution')

plt.tight_layout()
plt.show()


# Visualize missing data
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()
# Out:
# /Library/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
